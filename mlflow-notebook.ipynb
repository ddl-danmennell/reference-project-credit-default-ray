# %%
# Out:
# Cannot show ipywidgets in text

# %% [markdown]
# # Model Training with MLflow Integration
#
# This notebook extends the original credit risk prediction model with MLflow tracking capabilities.

# %%
import os
import ray
import glob
import eli5
import mlflow
import xgboost_ray as xgbr
import xgboost as xgb
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error
from ray import tune

# Set up MLflow tracking URI - replace with your MLflow server URL
#mlflow.set_tracking_uri('http://your-mlflow-server:5000')
#mlflow.set_experiment('credit-risk-prediction')

# Enable MLflow autologging for XGBoost
mlflow.xgboost.autolog()

DATA_ROOT = os.path.join("/mnt/data", os.environ["DOMINO_PROJECT_NAME"], "data") 
MODEL_ROOT = "/mnt/artifacts"
TUNE_ROOT = os.path.join("/mnt/data", os.environ["DOMINO_PROJECT_NAME"], "ray_results")

# %%
# Ray setup
RAY_ACTORS = 3
RAY_CPUS_PER_ACTOR = 4

if ray.is_initialized() == False:
    service_host = os.environ["RAY_HEAD_SERVICE_HOST"]
    service_port = os.environ["RAY_HEAD_SERVICE_PORT"]
    ray.init(f"ray://{service_host}:{service_port}")

# %%
train_files = glob.glob(os.path.join(DATA_ROOT, "train_data*"))
val_files = glob.glob(os.path.join(DATA_ROOT, "validation_data*"))
test_file = os.path.join(DATA_ROOT, "test_data.csv")
target_col = "credit"

rdm_train = xgbr.RayDMatrix(train_files, label=target_col)
rdm_val = xgbr.RayDMatrix(val_files, label=target_col)
df_test = pd.read_csv(test_file)
rdm_test = xgbr.RayDMatrix(df_test, label=target_col)

# %% [markdown]
# ## Initial Model Training with MLflow Tracking

# %%
with mlflow.start_run(run_name='initial_model') as run:
    param = {
        "seed": 1234,
        "max_depth": 3,
        "eta": 0.1,
        "objective": "binary:logistic",
        "eval_metric": ["logloss", "error"]
    }
    
    mlflow.log_params(param)
    
    xgb_ray_params = xgbr.RayParams(
        num_actors=RAY_ACTORS,
        cpus_per_actor=RAY_CPUS_PER_ACTOR
    )
    
    evals_result = {}
    bst = xgbr.train(
        param,
        rdm_train,
        num_boost_round=50,
        verbose_eval=True,
        evals_result=evals_result,
        evals=[(rdm_train, "train"), (rdm_val, "val")],
        ray_params=xgb_ray_params
    )
    
    mlflow.log_metric("train_error", evals_result["train"]["error"][-1])
    mlflow.log_metric("val_error", evals_result["val"]["error"][-1])
    
    print(f"Final training error: {evals_result['train']['error'][-1]:.4f}")
    print(f"Final validation error: {evals_result['val']['error'][-1]:.4f}")
# Out:
# /opt/conda/lib/python3.9/site-packages/xgboost_ray/util.py:89: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# Use get_node_id() instead
#   current_node_id = ray.get_runtime_context().node_id.hex()
# (_wrapped pid=458) 2025-01-22 12:57:10,401	INFO main.py:1047 -- [RayXGBoost] Created 3 new actors (3 total actors). Waiting until actors are ready for training.
# (_wrapped pid=458) 2025-01-22 12:57:21,182	INFO main.py:1092 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=173, ip=100.64.57.144) [12:57:21] task [xgboost.ray]:124137787360064 got new rank 0
# (_RemoteRayXGBoostActor pid=210, ip=100.64.68.246) [12:57:21] task [xgboost.ray]:128020571211280 got new rank 1
# (_RemoteRayXGBoostActor pid=172, ip=100.64.73.105) [12:57:21] task [xgboost.ray]:134138783786944 got new rank 2
# (_wrapped pid=458) [0]	train-logloss:0.65890	train-error:0.22747	val-logloss:0.65631	val-error:0.20883
# (_wrapped pid=458) [1]	train-logloss:0.63109	train-error:0.22331	val-logloss:0.62514	val-error:0.20021
# (_wrapped pid=458) [2]	train-logloss:0.60870	train-error:0.22340	val-logloss:0.60081	val-error:0.20959
# (_wrapped pid=458) [3]	train-logloss:0.58690	train-error:0.18629	val-logloss:0.57680	val-error:0.15792
# (_wrapped pid=458) [4]	train-logloss:0.56898	train-error:0.19034	val-logloss:0.55650	val-error:0.16499
# (_wrapped pid=458) [5]	train-logloss:0.55210	train-error:0.20139	val-logloss:0.53913	val-error:0.17972
# (_wrapped pid=458) [6]	train-logloss:0.53646	train-error:0.18746	val-logloss:0.52258	val-error:0.16193
# (_wrapped pid=458) [7]	train-logloss:0.52353	train-error:0.18899	val-logloss:0.50922	val-error:0.16659
# (_wrapped pid=458) [8]	train-logloss:0.51097	train-error:0.17833	val-logloss:0.49647	val-error:0.15485
# (_wrapped pid=458) [9]	train-logloss:0.50000	train-error:0.16964	val-logloss:0.48488	val-error:0.14864
# (_wrapped pid=458) [10]	train-logloss:0.48907	train-error:0.17604	val-logloss:0.47422	val-error:0.15407
# (_wrapped pid=458) [11]	train-logloss:0.47958	train-error:0.16847	val-logloss:0.46584	val-error:0.15177
# (_wrapped pid=458) [12]	train-logloss:0.47029	train-error:0.16078	val-logloss:0.45612	val-error:0.14937
# (_wrapped pid=458) [13]	train-logloss:0.46178	train-error:0.15817	val-logloss:0.44821	val-error:0.14318
# (_wrapped pid=458) [14]	train-logloss:0.45434	train-error:0.15810	val-logloss:0.44076	val-error:0.14472
# (_wrapped pid=458) [15]	train-logloss:0.44655	train-error:0.15260	val-logloss:0.43282	val-error:0.14318
# (_wrapped pid=458) [16]	train-logloss:0.43730	train-error:0.15222	val-logloss:0.42301	val-error:0.13769
# (_wrapped pid=458) [17]	train-logloss:0.43032	train-error:0.15077	val-logloss:0.41620	val-error:0.13851
# (_wrapped pid=458) [18]	train-logloss:0.42397	train-error:0.15001	val-logloss:0.41004	val-error:0.13851
# (_wrapped pid=458) [19]	train-logloss:0.41736	train-error:0.14292	val-logloss:0.40320	val-error:0.13227
# (_wrapped pid=458) [20]	train-logloss:0.41217	train-error:0.14372	val-logloss:0.39834	val-error:0.13232
# (_wrapped pid=458) [21]	train-logloss:0.40661	train-error:0.14114	val-logloss:0.39309	val-error:0.12839
# (_wrapped pid=458) [22]	train-logloss:0.40050	train-error:0.14146	val-logloss:0.38700	val-error:0.13227
# (_wrapped pid=458) [23]	train-logloss:0.39205	train-error:0.13223	val-logloss:0.37814	val-error:0.12055
# (_wrapped pid=458) [24]	train-logloss:0.38539	train-error:0.13143	val-logloss:0.37213	val-error:0.12212
# (_wrapped pid=458) [25]	train-logloss:0.38187	train-error:0.12851	val-logloss:0.36846	val-error:0.11823
# (_wrapped pid=458) [26]	train-logloss:0.37518	train-error:0.12725	val-logloss:0.36113	val-error:0.11739
# (_wrapped pid=458) [27]	train-logloss:0.37013	train-error:0.12735	val-logloss:0.35584	val-error:0.11820
# (_wrapped pid=458) [28]	train-logloss:0.36639	train-error:0.12081	val-logloss:0.35223	val-error:0.11037
# (_wrapped pid=458) [29]	train-logloss:0.36194	train-error:0.12386	val-logloss:0.34761	val-error:0.11433
# (_wrapped pid=458) [30]	train-logloss:0.35791	train-error:0.12588	val-logloss:0.34378	val-error:0.11668
# (_wrapped pid=458) [31]	train-logloss:0.35449	train-error:0.12364	val-logloss:0.34068	val-error:0.11434
# (_wrapped pid=458) [32]	train-logloss:0.35040	train-error:0.11787	val-logloss:0.33605	val-error:0.10798
# (_wrapped pid=458) 2025-01-22 12:57:51,678	INFO main.py:1175 -- Training in progress (30 seconds since last restart).
# (_wrapped pid=458) [33]	train-logloss:0.34684	train-error:0.11448	val-logloss:0.33241	val-error:0.10723
# (_wrapped pid=458) [34]	train-logloss:0.34377	train-error:0.11517	val-logloss:0.32920	val-error:0.10568
# (_wrapped pid=458) [35]	train-logloss:0.33971	train-error:0.11360	val-logloss:0.32577	val-error:0.10412
# (_wrapped pid=458) [36]	train-logloss:0.33605	train-error:0.10761	val-logloss:0.32224	val-error:0.10097
# (_wrapped pid=458) [37]	train-logloss:0.33335	train-error:0.10382	val-logloss:0.31979	val-error:0.09627
# (_wrapped pid=458) [38]	train-logloss:0.32945	train-error:0.10460	val-logloss:0.31619	val-error:0.09786
# (_wrapped pid=458) [39]	train-logloss:0.32654	train-error:0.10505	val-logloss:0.31294	val-error:0.09787
# (_wrapped pid=458) [40]	train-logloss:0.32362	train-error:0.10278	val-logloss:0.31013	val-error:0.09549
# (_wrapped pid=458) [41]	train-logloss:0.32094	train-error:0.10403	val-logloss:0.30769	val-error:0.09625
# (_wrapped pid=458) [42]	train-logloss:0.31872	train-error:0.10445	val-logloss:0.30540	val-error:0.09625
# (_wrapped pid=458) [43]	train-logloss:0.31621	train-error:0.10007	val-logloss:0.30290	val-error:0.09464
# (_wrapped pid=458) [44]	train-logloss:0.31294	train-error:0.09748	val-logloss:0.29985	val-error:0.09074
# (_wrapped pid=458) [45]	train-logloss:0.30965	train-error:0.09973	val-logloss:0.29604	val-error:0.09308
# (_wrapped pid=458) [46]	train-logloss:0.30799	train-error:0.10017	val-logloss:0.29447	val-error:0.09229
# (_wrapped pid=458) [47]	train-logloss:0.30534	train-error:0.09666	val-logloss:0.29205	val-error:0.08917
# (_wrapped pid=458) [48]	train-logloss:0.30380	train-error:0.09397	val-logloss:0.29036	val-error:0.08603
# (_wrapped pid=458) [49]	train-logloss:0.30177	train-error:0.09410	val-logloss:0.28866	val-error:0.08762
# (_wrapped pid=458) 2025-01-22 12:58:04,726	INFO main.py:1587 -- [RayXGBoost] Finished XGBoost training on training data with total N=2,100,000 in 55.32 seconds (43.53 pure XGBoost training time).
# Final training error: 0.0941
# Final validation error: 0.0876

# %% [markdown]
# ## Hyperparameter Tuning with MLflow

# %%
config = {
    "seed": 1234,
    "eta": tune.loguniform(3e-3, 3e-1),
    "max_depth": tune.randint(2, 6),
    "objective": "binary:logistic",
    "eval_metric": ["logloss", "error"]
}

# %%
def my_trainer(config):
    with mlflow.start_run(nested=True) as run:
        mlflow.log_params(config)
        
        evals_result = {}
        bst = xgbr.train(
            params=config,
            dtrain=rdm_train,
            num_boost_round=50,
            evals_result=evals_result,
            evals=[(rdm_train, "train"), (rdm_val, "val")],
            ray_params=xgb_ray_params
        )
        
        mlflow.log_metric("train_error", evals_result["train"]["error"][-1])
        mlflow.log_metric("val_error", evals_result["val"]["error"][-1])
        
        bst.save_model("model.xgb")
        mlflow.log_artifact("model.xgb")

# %%
with mlflow.start_run(run_name='hyperparameter_tuning') as run:
    analysis = tune.run(
        my_trainer,
        config=config,
        resources_per_trial=xgb_ray_params.get_tune_resources(),
        local_dir=TUNE_ROOT,
        metric="val-error",
        mode="min",
        num_samples=10,
        verbose=1,
        progress_reporter=tune.JupyterNotebookReporter(overwrite=True)
    )
    
    mlflow.log_params({"best_" + k: v for k, v in analysis.best_config.items()})
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-22 13:00:28</td></tr>
# <tr><td>Running for: </td><td>00:00:46.06        </td></tr>
# <tr><td>Memory:      </td><td>3.4/30.8 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/12 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 10<br><table>
# <thead>
# <tr><th>Trial name            </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                  </th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainer_ca21d_00000</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00000_0_eta=0.1976,max_depth=2_2025-01-22_12-59-42/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00001</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00001_1_eta=0.0110,max_depth=2_2025-01-22_12-59-49/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00002</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00002_2_eta=0.0176,max_depth=4_2025-01-22_12-59-55/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00003</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00003_3_eta=0.2888,max_depth=5_2025-01-22_13-00-01/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00004</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00004_4_eta=0.1330,max_depth=4_2025-01-22_13-00-05/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00005</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00005_5_eta=0.0394,max_depth=4_2025-01-22_13-00-09/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00006</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00006_6_eta=0.0966,max_depth=4_2025-01-22_13-00-13/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00007</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00007_7_eta=0.2250,max_depth=5_2025-01-22_13-00-17/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00008</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00008_8_eta=0.0460,max_depth=3_2025-01-22_13-00-21/error.txt</td></tr>
# <tr><td>my_trainer_ca21d_00009</td><td style="text-align: right;">           1</td><td>/mnt/data/Demo-Credit-Default-Model/ray_results/my_trainer_2025-01-22_12-59-37/my_trainer_ca21d_00009_9_eta=0.0049,max_depth=2_2025-01-22_13-00-25/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc               </th><th style="text-align: right;">       eta</th><th style="text-align: right;">  max_depth</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainer_ca21d_00000</td><td>ERROR   </td><td>100.64.73.105:252 </td><td style="text-align: right;">0.19758   </td><td style="text-align: right;">          2</td></tr>
# <tr><td>my_trainer_ca21d_00001</td><td>ERROR   </td><td>100.64.68.246:293 </td><td style="text-align: right;">0.0109623 </td><td style="text-align: right;">          2</td></tr>
# <tr><td>my_trainer_ca21d_00002</td><td>ERROR   </td><td>100.64.57.144:255 </td><td style="text-align: right;">0.0176089 </td><td style="text-align: right;">          4</td></tr>
# <tr><td>my_trainer_ca21d_00003</td><td>ERROR   </td><td>100.64.73.105:351 </td><td style="text-align: right;">0.288773  </td><td style="text-align: right;">          5</td></tr>
# <tr><td>my_trainer_ca21d_00004</td><td>ERROR   </td><td>100.64.73.105:450 </td><td style="text-align: right;">0.133049  </td><td style="text-align: right;">          4</td></tr>
# <tr><td>my_trainer_ca21d_00005</td><td>ERROR   </td><td>100.64.38.234:1388</td><td style="text-align: right;">0.0394136 </td><td style="text-align: right;">          4</td></tr>
# <tr><td>my_trainer_ca21d_00006</td><td>ERROR   </td><td>100.64.38.234:1551</td><td style="text-align: right;">0.0966059 </td><td style="text-align: right;">          4</td></tr>
# <tr><td>my_trainer_ca21d_00007</td><td>ERROR   </td><td>100.64.73.105:549 </td><td style="text-align: right;">0.224958  </td><td style="text-align: right;">          5</td></tr>
# <tr><td>my_trainer_ca21d_00008</td><td>ERROR   </td><td>100.64.68.246:392 </td><td style="text-align: right;">0.0460114 </td><td style="text-align: right;">          3</td></tr>
# <tr><td>my_trainer_ca21d_00009</td><td>ERROR   </td><td>100.64.73.105:648 </td><td style="text-align: right;">0.00488958</td><td style="text-align: right;">          2</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (run pid=804) UserWarning: The `local_dir` argument of `Experiment is deprecated. Use `storage_path` or set the `TUNE_RESULT_DIR` environment variable instead.
# (run pid=804) 2025-01-22 12:59:48,305	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00000: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=252, ip=100.64.73.105, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 12:59:54,333	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00001: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=293, ip=100.64.68.246, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 13:00:00,382	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00002: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=255, ip=100.64.57.144, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 13:00:04,742	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00003: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=351, ip=100.64.73.105, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 13:00:08,770	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00004: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=450, ip=100.64.73.105, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 13:00:12,899	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00005: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=1388, ip=100.64.38.234, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# ...
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# (run pid=804) 2025-01-22 13:00:28,672	ERROR trial_runner.py:1450 -- Trial my_trainer_ca21d_00009: Error happened when processing _ExecutorEventType.TRAINING_RESULT.
# (run pid=804) ray.exceptions.RayTaskError(MlflowException): ray::ImplicitFunc.train() (pid=648, ip=100.64.73.105, repr=my_trainer)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 384, in train
# (run pid=804)     raise skipped from exception_cause(skipped)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 336, in entrypoint
# (run pid=804)     return self._trainable_func(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 653, in _trainable_func
# (run pid=804)     output = fn()
# (run pid=804)   File "/tmp/ipykernel_3623/1270148858.py", line 2, in my_trainer
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/fluent.py", line 350, in start_run
# (run pid=804)     active_run_obj = client.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/client.py", line 270, in create_run
# (run pid=804)     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py", line 108, in create_run
# (run pid=804)     return self.store.create_run(
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 204, in create_run
# (run pid=804)     response_proto = self._call_endpoint(CreateRun, req_body)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py", line 57, in _call_endpoint
# (run pid=804)     return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 280, in call_endpoint
# (run pid=804)     response = verify_rest_response(response, endpoint)
# (run pid=804)   File "/home/ray/anaconda3/lib/python3.9/site-packages/mlflow/utils/rest_utils.py", line 212, in verify_rest_response
# (run pid=804)     raise MlflowException(
# (run pid=804) mlflow.exceptions.MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 404 != 200. Response body: '<!DOCTYPE HTML>
# (run pid=804) <html>
# (run pid=804)
# (run pid=804) <head>
# (run pid=804)
# (run pid=804)     <meta charset="utf-8">
# (run pid=804)
# (run pid=804)     <title>Jupyter Server</title>
# (run pid=804)     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
# (run pid=804)
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
# (run pid=804)     <link rel="stylesheet" href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
# (run pid=804)     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# (run pid=804)     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) <style type="text/css">
# (run pid=804)     /* disable initial hide */
# (run pid=804)     div#header,
# (run pid=804)     div#site {
# (run pid=804)         display: block;
# (run pid=804)     }
# (run pid=804) </style>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804) </head>
# (run pid=804)
# (run pid=804) <body class=""    dir="ltr">
# (run pid=804)
# (run pid=804)   <noscript>
# (run pid=804)     <div id='noscript'>
# (run pid=804)       Jupyter Server requires JavaScript.<br>
# (run pid=804)       Please enable it to proceed.
# (run pid=804)     </div>
# (run pid=804)   </noscript>
# (run pid=804)
# (run pid=804)   <div id="header" role="navigation" aria-label="Top Menu">
# (run pid=804)     <div id="header-container" class="container">
# (run pid=804)       <div id="jupyter_server" class="nav navbar-brand"><a href="/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/lab/tree/mnt/code" title='dashboard'>
# (run pid=804)           <img src='/dmennell/Demo-Credit-Default-Model/notebookSession/67914e5da12d5146bf75c2f2/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
# (run pid=804)         </a></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)     </div>
# (run pid=804)     <div class="header-bar"></div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)   <div id="site">
# (run pid=804)
# (run pid=804)
# (run pid=804) <div class="error">
# (run pid=804)
# (run pid=804)     <h1>404 : Not Found</h1>
# (run pid=804)
# (run pid=804)
# (run pid=804) <p>You are requesting a page that does not exist!</p>
# (run pid=804)
# (run pid=804) </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)   </div>
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)
# (run pid=804)   <script type='text/javascript'>
# (run pid=804)     function _remove_token_from_url() {
# (run pid=804)       if (window.location.search.length <= 1) {
# (run pid=804)         return;
# (run pid=804)       }
# (run pid=804)       var search_parameters = window.location.search.slice(1).split('&');
# (run pid=804)       for (var i = 0; i < search_parameters.length; i++) {
# (run pid=804)         if (search_parameters[i].split('=')[0] === 'token') {
# (run pid=804)           // remote token from search parameters
# (run pid=804)           search_parameters.splice(i, 1);
# (run pid=804)           var new_search = '';
# (run pid=804)           if (search_parameters.length) {
# (run pid=804)             new_search = '?' + search_parameters.join('&');
# (run pid=804)           }
# (run pid=804)           var new_url = window.location.origin +
# (run pid=804)             window.location.pathname +
# (run pid=804)             new_search +
# (run pid=804)             window.location.hash;
# (run pid=804)           window.history.replaceState({}, "", new_url);
# (run pid=804)           return;
# (run pid=804)         }
# (run pid=804)       }
# (run pid=804)     }
# (run pid=804)     _remove_token_from_url();
# (run pid=804)   </script>
# (run pid=804) </body>
# (run pid=804)
# (run pid=804) </html>'
# ---------------------------------------------------------------------------
# RayTaskError(TuneError)                   Traceback (most recent call last)
# Cell In[8], line 2
#       1 with mlflow.start_run(run_name='hyperparameter_tuning') as run:
# ----> 2     analysis = tune.run(
#       3         my_trainer,
#       4         config=config,
#       5         resources_per_trial=xgb_ray_params.get_tune_resources(),
#       6         local_dir=TUNE_ROOT,
#       7         metric="val-error",
#       8         mode="min",
#       9         num_samples=10,
#      10         verbose=1,
#      11         progress_reporter=tune.JupyterNotebookReporter(overwrite=True)
#      12     )
#      14     mlflow.log_params({"best_" + k: v for k, v in analysis.best_config.items()})
#
# File /opt/conda/lib/python3.9/site-packages/ray/tune/tune.py:537, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, chdir_to_trial_dir, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, trial_executor, _experiment_checkpoint_dir, _remote, _remote_string_queue, _tuner_api)
#     530     remote_future = remote_run.remote(_remote=False, **remote_run_kwargs)
#     532     _stream_client_output(
#     533         remote_future,
#     534         progress_reporter,
#     535         string_queue,
#     536     )
# --> 537     return ray.get(remote_future)
#     539 del remote_run_kwargs
#     541 ray._private.usage.usage_lib.record_library_usage("tune")
#
# File /opt/conda/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     100 if client_mode_should_convert(auto_init=auto_init):
#     101     # Legacy code
#     102     # we only convert init function if RAY_CLIENT_MODE=1
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
# --> 104         return getattr(ray, func.__name__)(*args, **kwargs)
#     105 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/ray/util/client/api.py:42, in _ClientAPI.get(self, vals, timeout)
#      35 def get(self, vals, *, timeout=None):
#      36     """get is the hook stub passed on to replace `ray.get`
#      37
#      38     Args:
#      39         vals: [Client]ObjectRef or list of these refs to retrieve.
#      40         timeout: Optional timeout in milliseconds
#      41     """
# ---> 42     return self.worker.get(vals, timeout=timeout)
#
# File /opt/conda/lib/python3.9/site-packages/ray/util/client/worker.py:434, in Worker.get(self, vals, timeout)
#     432     op_timeout = max_blocking_operation_time
#     433 try:
# --> 434     res = self._get(to_get, op_timeout)
#     435     break
#     436 except GetTimeoutError:
#
# File /opt/conda/lib/python3.9/site-packages/ray/util/client/worker.py:462, in Worker._get(self, ref, timeout)
#     460         logger.exception("Failed to deserialize {}".format(chunk.error))
#     461         raise
# --> 462     raise err
#     463 if chunk.total_size > OBJECT_TRANSFER_WARNING_SIZE and log_once(
#     464     "client_object_transfer_size_warning"
#     465 ):
#     466     size_gb = chunk.total_size / 2**30
#
# RayTaskError(TuneError): ray::run() (pid=804, ip=100.64.38.234)
#   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/tune.py", line 939, in run
#     raise TuneError("Trials did not complete", incomplete_trials)
# ray.tune.error.TuneError: ('Trials did not complete', [my_trainer_ca21d_00000, my_trainer_ca21d_00001, my_trainer_ca21d_00002, my_trainer_ca21d_00003, my_trainer_ca21d_00004, my_trainer_ca21d_00005, my_trainer_ca21d_00006, my_trainer_ca21d_00007, my_trainer_ca21d_00008, my_trainer_ca21d_00009])

# %% [markdown]
# ## Final Model Evaluation with MLflow Tracking

# %%
with mlflow.start_run(run_name='final_model_evaluation') as run:
    bst = xgb.Booster(model_file=os.path.join(MODEL_ROOT, "tune_best.xgb"))
    mlflow.log_artifact(os.path.join(MODEL_ROOT, "tune_best.xgb"))
    
    xgb_ray_params = xgbr.RayParams(
        num_actors=RAY_ACTORS,
        cpus_per_actor=RAY_CPUS_PER_ACTOR
    )
    
    predictions = xgbr.predict(bst, rdm_test, ray_params=xgb_ray_params)
    pred_class = (predictions > 0.5).astype("int")
    actuals = df_test[target_col]
    
    accuracy = accuracy_score(pred_class, actuals)
    precision = precision_score(pred_class, actuals)
    recall = recall_score(pred_class, actuals)
    f1 = f1_score(pred_class, actuals)
    
    mlflow.log_metrics({
        "test_accuracy": accuracy,
        "test_precision": precision,
        "test_recall": recall,
        "test_f1": f1
    })
    
    # Log feature importance plot
    fig, ax = plt.subplots(figsize=(10, 6))
    xgb.plot_importance(bst, importance_type="gain", max_num_features=10, ax=ax)
    plt.title("Feature Importance (Gain)")
    mlflow.log_figure(fig, "feature_importance.png")
    plt.close()
    
    # Log model to MLflow model registry
    mlflow.xgboost.log_model(bst, "model")
    
    print(f"Accuracy on test: {accuracy:.2f}")
    print(f"Precision on test: {precision:.2f}")
    print(f"Recall on test: {recall:.2f}")
    print(f"F1 score on test: {f1:.2f}")
